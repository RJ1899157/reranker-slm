# %% [markdown]
# # 🚀 reranker-slm: Training Notebook
# Fine-tune `Qwen/Qwen2.5-0.5B-Instruct` for passage relevance reranking using LoRA/QLoRA on a free Colab GPU.

# %% [markdown]
# ## 1. Setup & Dependencies

# %%
# !pip install -q datasets transformers peft trl bitsandbytes torch accelerate rank_bm25 scikit-learn pandas tqdm pyyaml sentence-transformers
print("✅ Dependencies installed")

# %% [markdown]
# ## 2. GPU Check

# %%
import torch
if torch.cuda.is_available():
    print(f"🟢 GPU: {torch.cuda.get_device_name(0)} ({torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB)")
else:
    print("❌ No GPU detected! Go to Runtime -> Change runtime type -> T4 GPU")

# %% [markdown]
# ## 3. Clone Repository & Prepare Environment

# %%
# Clone repo or upload project files
# !git clone https://github.com/RJ1899157/reranker-slm.git
# %cd reranker-slm

# %% [markdown]
# ## 4. Download & Preprocess MS MARCO Data

# %%
# !python data/download.py
# !python data/preprocess.py

# %% [markdown]
# ## 5. Fine-Tune with LoRA

# %%
# !python model/train.py

# %% [markdown]
# ## 6. Evaluate Against Baselines

# %%
# !python eval/baselines.py
# !python eval/evaluate.py

# %% [markdown]
# ## 7. Inference Smoke Test

# %%
# !python inference/reranker.py
